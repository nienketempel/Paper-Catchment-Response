# %% [markdown]
# # Load packages

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
    
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt

from scipy import optimize
from scipy.optimize import minimize
from scipy.stats import gumbel_r
from matplotlib.pyplot import cm
import math
import matplotlib
import matplotlib.colors as mcolors
from scipy.optimize import fsolve

import sympy
from sympy import *
from sympy import symbols, Eq, solve
from shapely.geometry import LineString


# %matplotlib inline
plt.style.use('ggplot')
import warnings
from scipy.stats import pearsonr

# %% [markdown]
# # Catchment selection

# %%
"""
LamaH: Catchment selection
The data set contains a selection of catchments with no human impact.
Snow fraction is checked by frac_snow < 0.1

"""

frac_snow = pd.read_csv('1_Data/LamaH/C_basins_intermediate_lowimp/1_attributes/Catchment_attributes.csv', delimiter=';', parse_dates=[0,1,2], skipinitialspace=True)
# display(frac_snow)

catchment_list_Lamah = []
for i in range(len(frac_snow)):
    if (frac_snow['frac_snow'][i]<0.1):
        catchment_list_Lamah.append(int(frac_snow['ID'][i]))
        
# print(catchment_list_Lamah)

# %% [markdown]
# # Catchment descriptors

# %%
#FUNCTIONS to compute the catchment descriptors.

#HAI
def HAI_calculate(temp, precipitation):

    temp_adjusted = np.zeros(12)
    
    for i in range(1,13):
        if temp[i] < 0:
            temp_adjusted[i-1] = 0
        elif temp[i] > 30:
            temp_adjusted[i-1] = 30
        else:
            temp_adjusted[i-1] = temp[i]            
        
    T = np.sum(temp_adjusted)
    HAI = (58.93 * (T/12))/precipitation
    
    return HAI


#Function for the Seasonality Index
def Seasonality_index(Annual_mean, Monthly_mean):
    SI = (1/Annual_mean) * np.sum(np.abs(Monthly_mean - (Annual_mean/12)))
    
    return SI

#Function for Seasonality Timing Index
def ST_calc(dP,dT):
    days = 366
    ST = dP[0] * np.sign(dT[0]) * np.cos((np.pi * (dP[1] - dT[1]))/days)
    return ST

#Functions to compute Seasonal variability indexes
def T_daily(dT):
    t = np.linspace(1,366,366)
    days = 366
    T = T_mean + dT[0] * np.sin((2*np.pi * (t-dT[1]))/days)
    return T

def Cal_T_daily(dT):
    days = 366
    T_calc = T_daily(dT)
    
    return (np.sum(np.abs(T_calc - T_obs)))/days

def P_daily(dP):
    t = np.linspace(1,366,366)
    days = 366
    P = P_mean * (1 + dP[0] * np.sin((2*np.pi * (t-dP[1]))/days))
    return P

def Cal_P_daily(dP):
    days = 366
    P_calc = P_daily(dP)
    
    return (np.sum(np.abs(P_calc - P_obs)))/days

def E_daily(dE):
#    t = np.linspace(1,366,366)
    t = np.linspace(1,366,366)

    days = 366
    E = E_mean * (1 + dE[0] * np.sin((2*np.pi * (t-dE[1]))/days))
    return E

def Cal_E_daily(dE):
    days = 366
    E_calc = E_daily(dE)
    
    return (np.sum(np.abs(E_calc - E_obs)))/days


#Function for the interstorm duration or low_prec_freq
def Interstorm_duration(P):
    interstorm = []
    count = 0

    for j in range(len(P)):
        if P[j] < 1:
            count += 1
        elif P[j] >= 1 and count > 0:
            interstorm.append(count)
            count = 0 
    interstorm_duration = np.mean(interstorm)
    return 

#Function to compute the root-zone storage capacity
def rootzone(df_out, RP):
    firstyear = df_out['hydroyear'].iloc[0]
    lastyear = df_out['hydroyear'].iloc[-1]
    df_out = df_out.drop(df_out[df_out['hydroyear']==firstyear].index)
    df_out = df_out.drop(df_out[df_out['hydroyear']==lastyear].index)
    years = df_out.groupby(['hydroyear'])
    SD = years['SD_sum'].max() - years['SD_sum'].min()
    var = gumbel_r.fit(SD)
    p = 1-1/RP
    Sr = gumbel_r.ppf(p, var[0],var[1])
    return(Sr, df_out)

# %% [markdown]
# ## Load et0_mean

# %% [markdown]
# # LamaH: Load data

# %%
catch_att = pd.read_csv('1_Data/LamaH/C_basins_intermediate_lowimp/1_attributes/Catchment_attributes.csv', delimiter=';', parse_dates=[0,1,2], skipinitialspace=True)
catch_att.index = catch_att['ID']

# %%
catchment_list = catchment_list_Lamah

for i in range(len(catchment_list)): 
    # Import data and select right dates
    data = pd.read_csv('1_Data/LamaH/C_basins_intermediate_lowimp/2_timeseries/daily/'+str('ID_')+str(catchment_list[i])+str('.csv'),delimiter=';', skipinitialspace=True)
    data['date'] = pd.to_datetime(data['YYYY'].astype('str')+
                                 data['MM'].astype('str')+
                                 data['DD'].astype('str'),
                           format='%Y%m%d')
    data.loc[:,'dt'] = pd.to_datetime(data['date'])
    data.index = data['dt']
    data = data["1989-01-01":"2009-12-31"]
    
    
    outputdata = pd.read_csv('1_Data/LamaH/F_hydrol_model/2_timeseries/'+str('ID_')+str(catchment_list[i])+str('.csv'),delimiter=';', skipinitialspace=True)
    outputdata['date'] = pd.to_datetime(outputdata['YYYY'].astype('str')+
                                 outputdata['MM'].astype('str')+
                                 outputdata['DD'].astype('str'),
                                        format='%Y%m%d')
    outputdata.loc[:,'dt'] = pd.to_datetime(outputdata['date'])
    outputdata.index = outputdata['dt']
    outputdata = outputdata["1989-01-01":"2009-12-31"]   
    
    data["qobs"] = outputdata["Qobs"]    
    
    # Compute mean values
    Ep = catch_att.loc[f"{catchment_list[i]}","et0_mean"]  # comes from catchment attributes 
    P = data['prec'].mean() 
    T = data['2m_temp_mean'].mean() 
    Q = data['qobs'].mean()
    Ea = data['total_et'].mean()
    
    # Compute Ea, AI, EI
    Ea = P - Q
    EI = Ea / P
    AI = Ep / P
# Out:
# 2.28 3.0608865710560598 8.473142112125142 1.1319556714471861 1.9289308996088737

# %% [markdown]
# # Plot Budyko

# %%
catchment_list = catchment_list_Lamah
plt.figure(figsize=(10,5)).suptitle("LamaH (n=59)",fontsize=20)
n_total = 0

for i in range(len(catchment_list)): 
    # Import data and select right dates
    data = pd.read_csv('1_Data/LamaH/C_basins_intermediate_lowimp/2_timeseries/daily/'+str('ID_')+str(catchment_list[i])+str('.csv'),delimiter=';', skipinitialspace=True)
    data['date'] = pd.to_datetime(data['YYYY'].astype('str')+
                                 data['MM'].astype('str')+
                                 data['DD'].astype('str'),
                           format='%Y%m%d')
    data.loc[:,'dt'] = pd.to_datetime(data['date'])
    data.index = data['dt']
    data = data["1989-01-01":"2009-12-31"]
    
    
    outputdata = pd.read_csv('1_Data/LamaH/F_hydrol_model/2_timeseries/'+str('ID_')+str(catchment_list[i])+str('.csv'),delimiter=';', skipinitialspace=True)
    outputdata['date'] = pd.to_datetime(outputdata['YYYY'].astype('str')+
                                 outputdata['MM'].astype('str')+
                                 outputdata['DD'].astype('str'),
                                        format='%Y%m%d')
    outputdata.loc[:,'dt'] = pd.to_datetime(outputdata['date'])
    outputdata.index = outputdata['dt']
    outputdata = outputdata["1989-01-01":"2009-12-31"]   
    
    data["qobs"] = outputdata["Qobs"]    
    
    # Compute mean values
    Ep = catch_att.loc[f"{catchment_list[i]}","et0_mean"]  # comes from catchment attributes 
    P = data['prec'].mean() 
    T = data['2m_temp_mean'].mean() 
    Q = data['qobs'].mean()
    Ea_calc = data['total_et'].mean()
    
    # display(data)
    
    # Compute Ea, AI, EI
    Ea = P - Q
    EI = Ea / P
    AI = Ep / P
    
    print(f'Catchment nr {i} has a given Ea of {Ea_calc} and Ea from P-Q of {Ea}, EI of {EI} and AI of {AI}')
        
        
    # Plot every catchment
    if Ea > 0 and AI > EI: 
        budyko_curve_x = np.arange(1, 3, 0.05)
        energy_limit_x = np.arange(0, 1.0001, 0.05)
        x = np.arange(0, 1.0001, 0.05)
        water_limit_y = 1 + budyko_curve_x*0
        energy_limit_y = energy_limit_x
        y = 1 + x*0
        plt.ylabel("Actual ET/P")
        plt.xlabel("Potential ET/P")
        plt.minorticks_on()
        plt.plot(energy_limit_x, energy_limit_y, c='k')
        plt.plot(budyko_curve_x, water_limit_y,c='k')
        
        plt.plot(AI, EI, marker='.', c = 'b')
        n_total += 1

        
plt.savefig(f'2_Output/Output3/Budyko.png')   
plt.close()

print(n_total)
# Out:
# Catchment nr 0 has a given Ea of 1.704422425032596 and Ea from P-Q of 1.2975293350716823, EI of 0.29613018236373434 and AI of 0.5386138189621771
# Catchment nr 1 has a given Ea of 1.6221408083441957 and Ea from P-Q of 3.057956975228156, EI of 0.8042332559772655 and AI of 0.6022629393111485
# Catchment nr 2 has a given Ea of 1.6791655801825316 and Ea from P-Q of 2.7714576271186377, EI of 0.772998219605287 and AI of 0.6331346874418181
# Catchment nr 3 has a given Ea of 1.6111877444589378 and Ea from P-Q of 2.734398956975211, EI of 0.7250936236357488 and AI of 0.6045984832141283
# Catchment nr 4 has a given Ea of 1.7969100391134345 and Ea from P-Q of -1.0682086049543655, EI of -0.30419519794578387 and AI of 0.6407355194515152
# Catchment nr 5 has a given Ea of 1.752791395045628 and Ea from P-Q of 0.12822294654497401, EI of 0.0384935584436915 and AI of 0.6724659917530866
# Catchment nr 6 has a given Ea of 1.824807040417211 and Ea from P-Q of 2.695640156453706, EI of 0.7901501989939853 and AI of 0.6565922537951046
# Catchment nr 7 has a given Ea of 1.662887874837032 and Ea from P-Q of -1.6802803129074197, EI of -0.5150507807239042 and AI of 0.6835545427696682
# Catchment nr 8 has a given Ea of 1.6066923076923096 and Ea from P-Q of 73.62127640156451, EI of 22.663565122985425 and AI of 0.6926397370316927
# Catchment nr 9 has a given Ea of 1.614816166883967 and Ea from P-Q of 2.247363754889177, EI of 0.6875287180272628 and AI of 0.6883352159595653
# Catchment nr 10 has a given Ea of 1.6329074315515009 and Ea from P-Q of 0.6534015645371558, EI of 0.20525305693166607 and AI of 0.7036512804382599
# Catchment nr 11 has a given Ea of 1.5916349413298616 and Ea from P-Q of 2.0946766623207362, EI of 0.6884637898275056 and AI of 0.7362276560168586
# Catchment nr 12 has a given Ea of 1.597756192959586 and Ea from P-Q of 2.910421121251633, EI of 0.9304236956813526 and AI of 0.7192956716802374
# Catchment nr 13 has a given Ea of 1.5803546284224244 and Ea from P-Q of 1.2207535853976532, EI of 0.421710156520236 and AI of 0.7738095238095254
# Catchment nr 14 has a given Ea of 1.60308474576271 and Ea from P-Q of 2.4321212516297317, EI of 0.830722033380523 and AI of 0.7616849419810892
# Catchment nr 15 has a given Ea of 1.622603650586699 and Ea from P-Q of -1.8855945241199503, EI of -0.6895601265023116 and AI of 0.8118518914078846
# Catchment nr 16 has a given Ea of 1.5988409387222906 and Ea from P-Q of 1.2688565840938693, EI of 0.4191172987363769 and AI of 0.7431997705479726
# Catchment nr 17 has a given Ea of 1.6433741851368993 and Ea from P-Q of 0.5489426336375498, EI of 0.19375664394877262 and AI of 0.804756492087087
# Catchment nr 18 has a given Ea of 1.582809647979143 and Ea from P-Q of 2.512286831812272, EI of 0.875149762333197 and AI of 0.7837827035972902
# Catchment nr 19 has a given Ea of 1.579024771838334 and Ea from P-Q of 1.450591916558021, EI of 0.5172381090519595 and AI of 0.7987176483276971
# Catchment nr 20 has a given Ea of 1.5788305084745702 and Ea from P-Q of 1.8614380704041777, EI of 0.6917614510428101 and AI of 0.8212966260395976
# Catchment nr 21 has a given Ea of 1.586698826597135 and Ea from P-Q of -1.6592659713168114, EI of -0.6222558723195536 and AI of 0.8437922171138605
# Catchment nr 22 has a given Ea of 1.5704954367666175 and Ea from P-Q of 2.834305084745758, EI of 0.8663703193584611 and AI of 0.6938775347538564
# Catchment nr 23 has a given Ea of 1.556938722294653 and Ea from P-Q of 2.608129074315509, EI of 0.7752584343340002 and AI of 0.6806955346298535
# Catchment nr 24 has a given Ea of 1.5991368970013 and Ea from P-Q of -2.886976531942631, EI of -0.8860614577785403 and AI of 0.7089776951152236
# Catchment nr 25 has a given Ea of 1.6340808344198208 and Ea from P-Q of 0.25030769230770167, EI of 0.09830211672179809 and AI of 0.9111222619327963
# Catchment nr 26 has a given Ea of 1.6150508474576248 and Ea from P-Q of -3.7925945241199583, EI of -1.4281499083140796 and AI of 0.8547974931818524
# Catchment nr 27 has a given Ea of 1.6342542372881341 and Ea from P-Q of 1.6662411994785031, EI of 0.6422129592639234 and AI of 0.8749173997050204
# Catchment nr 28 has a given Ea of 1.6465736636245085 and Ea from P-Q of -0.08171447196869508, EI of -0.027395553768277126 and AI of 0.7945650368479477
# Catchment nr 29 has a given Ea of 1.718365058670145 and Ea from P-Q of -0.34400521512386595, EI of -0.12722264251745374 and AI of 0.8949829286203702
# Catchment nr 30 has a given Ea of 1.7738722294654534 and Ea from P-Q of 1001.1520143415906, EI of 465.21623717507714 and AI of 1.1384682493282674
# Catchment nr 31 has a given Ea of 1.6332451108213848 and Ea from P-Q of 1.607561929595845, EI of 0.8001116132988559 and AI of 1.1447501192380345
# Catchment nr 32 has a given Ea of 1.6475593220338993 and Ea from P-Q of 745.4334732724915, EI of 392.14047161315295 and AI of 1.262536719393518
# Catchment nr 33 has a given Ea of 1.7691734028683221 and Ea from P-Q of 0.7054784876140945, EI of 0.31167890106953555 and AI of 1.1221666182820171
# Catchment nr 34 has a given Ea of 1.7809778357236012 and Ea from P-Q of 0.9397496740547664, EI of 0.41869156706989585 and AI of 1.145025486124216
# Catchment nr 35 has a given Ea of 1.7993220338983054 and Ea from P-Q of 1.8156962190352153, EI of 0.8537114504228606 and AI of 1.2412859626451862
# Catchment nr 36 has a given Ea of 1.8585475880052167 and Ea from P-Q of 1.9474850065189235, EI of 0.9836203859488543 and AI of 1.3434918460813983
# Catchment nr 37 has a given Ea of 1.7342711864406855 and Ea from P-Q of 1.4298878748370423, EI of 0.7853831837005949 and AI of 1.4775149865477197
# Catchment nr 38 has a given Ea of 1.8860938722294625 and Ea from P-Q of 1.8117601043024996, EI of 0.9242524311493087 and AI of 1.362075467556839
# Catchment nr 39 has a given Ea of 1.800839634941333 and Ea from P-Q of 97.00826857887566, EI of 46.424011719971844 and AI of 1.2586056076678926
# Catchment nr 40 has a given Ea of 1.8626505867014427 and Ea from P-Q of 1.8995110821382184, EI of 0.8716491829289194 and AI of 1.211445336945343
# Catchment nr 41 has a given Ea of 1.8610756192959588 and Ea from P-Q of 12.68031812255553, EI of 6.124993702326618 and AI of 1.3428277057323827
# Catchment nr 42 has a given Ea of 1.6814706649282938 and Ea from P-Q of 1.6714511082138368, EI of 0.9039253678093345 and AI of 1.3033346447976362
# Catchment nr 43 has a given Ea of 1.6924654498044356 and Ea from P-Q of 908.2695554106915, EI of 509.5524237729685 and AI of 1.48668852209606
# Catchment nr 44 has a given Ea of 1.7708617992177347 and Ea from P-Q of 1.7415853976532112, EI of 0.9390276907849464 and AI of 1.4557854978204208
# Catchment nr 45 has a given Ea of 1.7609113428943926 and Ea from P-Q of 1.7702855280313032, EI of 0.9426237645413901 and AI of 1.5068898273256197
# Catchment nr 46 has a given Ea of 1.7230234680573673 and Ea from P-Q of 2.197910039113427, EI of 0.8615264243472344 and AI of 1.0308950119483462
# Catchment nr 47 has a given Ea of 1.8223233376792722 and Ea from P-Q of 2.2494445893090127, EI of 0.8409696094100753 and AI of 0.9907198761545285
# Catchment nr 48 has a given Ea of 1.711783572359838 and Ea from P-Q of 2.0086753585397745, EI of 0.8452337258710034 and AI of 1.1024740022657966
# Catchment nr 49 has a given Ea of 1.7548383311603672 and Ea from P-Q of 1.2476883963494294, EI of 0.5867942969826917 and AI of 1.2651208935675395
# Catchment nr 50 has a given Ea of 1.7260365058670186 and Ea from P-Q of 3.099058670143438, EI of 1.3522675295772129 and AI of 1.160685231076603
# Catchment nr 51 has a given Ea of 1.7689243807040445 and Ea from P-Q of 2.0503728813559565, EI of 0.9026035780760656 and AI of 1.1885787619243755
# Catchment nr 52 has a given Ea of 1.8684941329856546 and Ea from P-Q of 1.680970013037832, EI of 0.7824030555678639 and AI of 1.270671294034676
# Catchment nr 53 has a given Ea of 1.6255501955671445 and Ea from P-Q of 96.66555019556695, EI of 44.419913523656064 and AI of 1.1533993518767536
# Catchment nr 54 has a given Ea of 1.647813559322036 and Ea from P-Q of 0.04942503259452069, EI of 0.01935489470679824 and AI of 1.02599475346493
# Catchment nr 55 has a given Ea of 1.6672294654498059 and Ea from P-Q of 2.1876584093872413, EI of 0.8780834212061834 and AI of 1.0435892940779294
# Catchment nr 56 has a given Ea of 1.6552190352020846 and Ea from P-Q of 2.131387222946556, EI of 0.8311800167886005 and AI of 0.9710287363656168
# Catchment nr 57 has a given Ea of 1.6733168187744503 and Ea from P-Q of -3.1134732724902148, EI of -1.3340055404014 and AI of 1.0968631764409396
# Catchment nr 58 has a given Ea of 1.6639856584093873 and Ea from P-Q of 1.2375462842242575, EI of 0.5756273575179822 and AI of 1.186096859877011
# Catchment nr 59 has a given Ea of 1.6636388526727528 and Ea from P-Q of -6.346723598435428, EI of -2.5593215081475376 and AI of 0.98796451392766
# Catchment nr 60 has a given Ea of 1.7013428943937414 and Ea from P-Q of 3.4280860495436767, EI of 1.4661867374478623 and AI of 1.1205696696629717
# Catchment nr 61 has a given Ea of 1.699284224250322 and Ea from P-Q of 287.3689569752266, EI of 124.65296161926787 and AI of 1.1364858712649204
# Catchment nr 62 has a given Ea of 1.7547757496740555 and Ea from P-Q of 0.15479400260757958, EI of 0.0733769580764979 and AI of 1.2324772780928972
# Catchment nr 63 has a given Ea of 1.6871460234680546 and Ea from P-Q of 1.8793220338983228, EI of 0.8331377800794649 and AI of 1.157060666977233
# Catchment nr 64 has a given Ea of 1.7520182529335089 and Ea from P-Q of -0.7697366362451001, EI of -0.372355099268322 and AI of 1.2722454213077878
# Catchment nr 65 has a given Ea of 1.8295410691003895 and Ea from P-Q of 416.68628552802835, EI of 206.02290050255095 and AI of 1.2904666867791315
# Catchment nr 66 has a given Ea of 1.7040156453715747 and Ea from P-Q of 97.04831290743323, EI of 43.64041302293342 and AI of 1.1646639322541006
# Catchment nr 67 has a given Ea of 1.703649282920471 and Ea from P-Q of 1.7523963494133108, EI of 0.7148157130032654 and AI of 1.0524014959092203
# Catchment nr 68 has a given Ea of 1.6072438070404202 and Ea from P-Q of 287.6248617992195, EI of 114.54130367624366 and AI of 0.9836320070196712
# Catchment nr 69 has a given Ea of 1.6127118644067844 and Ea from P-Q of 192.0345893089951, EI of 88.74981848199627 and AI of 1.1507668947316017
# Catchment nr 70 has a given Ea of 1.828485006518902 and Ea from P-Q of 240.3015423728787, EI of 76.85573897502385 and AI of 0.7835844856818541
# Catchment nr 71 has a given Ea of 1.763603650586697 and Ea from P-Q of 0.4004850065188852, EI of 0.13383601937487227 and AI of 0.8354621096692738
# Catchment nr 72 has a given Ea of 1.6461238591916596 and Ea from P-Q of -0.23424380704041603, EI of -0.0825887634416751 and AI of 0.8532341155741606
# Catchment nr 73 has a given Ea of 1.628627118644072 and Ea from P-Q of 48.79265189048254, EI of 17.846830138777587 and AI of 0.892475892401975
# Catchment nr 74 has a given Ea of 1.6372007822685788 and Ea from P-Q of -3.031941329856554, EI of -1.1421670781678601 and AI of 0.9267102185073841
# Catchment nr 75 has a given Ea of 1.6439165580182524 and Ea from P-Q of 1.3143898305084876, EI of 0.577735230354945 and AI of 1.090074906259716
# Catchment nr 76 has a given Ea of 1.647723598435461 and Ea from P-Q of 1.4397953063885396, EI of 0.6510359586265049 and AI of 1.1168662730544563
# Catchment nr 77 has a given Ea of 1.5683194263363804 and Ea from P-Q of 1.4699700130377882, EI of 0.46494558224849136 and AI of 0.7211547978015176
# Catchment nr 78 has a given Ea of 1.5922046936114715 and Ea from P-Q of 875.3769595827897, EI of 327.18583608500177 and AI of 0.8708739586216568
# Catchment nr 79 has a given Ea of 1.5332229465449818 and Ea from P-Q of 2.442529335071708, EI of 0.816233523774171 and AI of 0.788654239868317
# Catchment nr 80 has a given Ea of 1.5570977835723654 and Ea from P-Q of 1001.7030247718384, EI of 370.58595807487796 and AI of 0.880495075293503
# Catchment nr 81 has a given Ea of 1.5971760104302424 and Ea from P-Q of 383.68112646675297, EI of 113.40445396706745 and AI of 0.6945884184524815
# Catchment nr 82 has a given Ea of 1.6159374185136917 and Ea from P-Q of 288.5071264667622, EI of 88.14631050960479 and AI of 0.7240956522154772
# Catchment nr 83 has a given Ea of 1.61659582790091 and Ea from P-Q of 3.0982529335071693, EI of 0.9554404411729223 and AI of 0.7246939113569217
# Catchment nr 84 has a given Ea of 1.600314211212511 and Ea from P-Q of -24.746809647979134, EI of -8.082891270122795 and AI of 0.774097856761725
# Catchment nr 85 has a given Ea of 1.611761408083446 and Ea from P-Q of 192.67153324641174, EI of 70.23753249777671 and AI of 0.8566818283356826
# Catchment nr 86 has a given Ea of 1.5613689700130378 and Ea from P-Q of 892.3350273793993, EI of 319.19552785506596 and AI of 0.8620766847961441
# Catchment nr 87 has a given Ea of 1.7330221642764065 and Ea from P-Q of -159.5383142112125, EI of -49.66944254456386 and AI of 0.6973845238989219
# Catchment nr 88 has a given Ea of 1.6183220338983053 and Ea from P-Q of -193.07706910039008, EI of -78.47621550869752 and AI of 0.9388999878117844
# Catchment nr 89 has a given Ea of 1.8526140808344143 and Ea from P-Q of 1.298737940026074, EI of 0.45718707488613125 and AI of 0.8096554661496922
# Catchment nr 90 has a given Ea of 1.7659700130378189 and Ea from P-Q of 0.1786610169491465, EI of 0.05158464111570499 and AI of 0.6640770135092878
# Catchment nr 91 has a given Ea of 1.821658409387226 and Ea from P-Q of -7.489087353324688, EI of -2.4836978587671217 and AI of 0.7660936217021196
# Catchment nr 92 has a given Ea of 1.6209947848761403 and Ea from P-Q of -4.478938722294647, EI of -1.762931868391265 and AI of 0.9052910853896626
# Catchment nr 93 has a given Ea of 1.6051460234680544 and Ea from P-Q of -2.590159061277715, EI of -1.02990994615225 and AI of 0.9145356791260763
# Catchment nr 94 has a given Ea of 1.5947157757496702 and Ea from P-Q of -9.499127770534537, EI of -3.8965913928578058 and AI of 0.9639821670385386
# Catchment nr 95 has a given Ea of 1.744628422425033 and Ea from P-Q of -0.35134028683181207, EI of -0.13439722784957853 and AI of 0.8836379087979275
# Catchment nr 96 has a given Ea of 1.7895893089960868 and Ea from P-Q of -0.34365189048238687, EI of -0.12184485295510818 and AI of 0.8225767606255584
# Catchment nr 97 has a given Ea of 1.5783272490221674 and Ea from P-Q of -0.6965488917861751, EI of -0.29123254590600184 and AI of 0.9616480098993948
# Catchment nr 98 has a given Ea of 1.5811395045632377 and Ea from P-Q of -1.3925645371577744, EI of -0.5417327075908295 and AI of 0.8986316405047411
# Catchment nr 99 has a given Ea of 1.5523389830508456 and Ea from P-Q of 1.6566479791395157, EI of 0.6873905538024943 and AI of 0.9709328210651661
# Catchment nr 100 has a given Ea of 1.563401564537155 and Ea from P-Q of 0.17505475880052224, EI of 0.07145267106025027 and AI of 0.9428802237662204
# Catchment nr 101 has a given Ea of 1.4939973924380696 and Ea from P-Q of -7.333318122555411, EI of -3.0499523364881203 and AI of 0.8817153224905604
# Catchment nr 102 has a given Ea of 1.5073689700130393 and Ea from P-Q of -0.2424524119947864, EI of -0.09614720432153467 and AI of 0.8446752231496573
# Catchment nr 103 has a given Ea of 1.579930899608869 and Ea from P-Q of -8.02956062581485, EI of -3.2913540052811765 and AI of 0.905889212454042
# Catchment nr 104 has a given Ea of 1.5722203389830494 and Ea from P-Q of 1.6864159061277881, EI of 0.7274356658482113 and AI of 0.983478222725115
# Catchment nr 105 has a given Ea of 1.7836518904824015 and Ea from P-Q of -17.641441981747047, EI of -5.412316462642945 and AI of 0.7332414413232468
# Catchment nr 106 has a given Ea of 1.7500026075619293 and Ea from P-Q of -19.777555410691093, EI of -6.435591835418708 and AI of 0.7711950407024227
# Catchment nr 107 has a given Ea of 1.7691981747066479 and Ea from P-Q of -1.547860495436768, EI of -0.4473433537685924 and AI of 0.6965081709628459
# Catchment nr 108 has a given Ea of 1.5990365058670164 and Ea from P-Q of -0.44512255541068013, EI of -0.16165474411495262 and AI of 0.8389205497820988
# Catchment nr 109 has a given Ea of 1.6134954367666265 and Ea from P-Q of 1.4731929595827833, EI of 0.5238627739243176 and AI of 0.8463204998569738
# Catchment nr 110 has a given Ea of 1.566586701434162 and Ea from P-Q of -1.5147940026075606, EI of -0.5212705961527652 and AI of 0.7880343222477677
# Catchment nr 111 has a given Ea of 1.6080104302477192 and Ea from P-Q of 0.07868839634940672, EI of 0.027406989295405547 and AI of 0.8115336951936293
# Catchment nr 112 has a given Ea of 1.5843142112125184 and Ea from P-Q of 8.379148631029981, EI of 2.941979420631904 and AI of 0.814568705773993
# Catchment nr 113 has a given Ea of 1.5876310299869656 and Ea from P-Q of 7.904447196870938, EI of 2.9568964129766315 and AI of 0.811753821152644
# Catchment nr 114 has a given Ea of 1.7104850065189108 and Ea from P-Q of 0.7523559322033933, EI of 0.23731117222195627 and AI of 0.7444008114664677
# Catchment nr 115 has a given Ea of 1.6883494132985646 and Ea from P-Q of -0.11070925684482225, EI of -0.03883483601045779 and AI of 0.8173225119846746
# Catchment nr 116 has a given Ea of 1.6266805736636303 and Ea from P-Q of 2.2155749674054817, EI of 0.8623259080488006 and AI of 0.8835087234999126
# Catchment nr 117 has a given Ea of 1.717076923076927 and Ea from P-Q of 1.3464146023468024, EI of 0.4559641586651068 and AI of 0.7280988630257541
# Catchment nr 118 has a given Ea of 1.820906127770536 and Ea from P-Q of 2.1205384615384606, EI of 0.6768990344597955 and AI of 0.7278008989512224
# Catchment nr 119 has a given Ea of 1.7180065189048253 and Ea from P-Q of 2.120702737940017, EI of 0.7201920714091177 and AI of 0.733537447947452
# Catchment nr 120 has a given Ea of 1.7346427640156477 and Ea from P-Q of 36.39676662320714, EI of 12.847133473633376 and AI of 0.7588953506298541
# Catchment nr 121 has a given Ea of 1.7891095176010432 and Ea from P-Q of 1.2375775749674136, EI of 0.3598566672403844 and AI of 0.6658748385952119
# Catchment nr 122 has a given Ea of 1.693016949152537 and Ea from P-Q of 2.635820078226873, EI of 0.9616422665691248 and AI of 0.802639377371788
# Catchment nr 123 has a given Ea of 1.5974784876140762 and Ea from P-Q of 2.509748370273812, EI of 0.901800483745615 and AI of 0.7940951741151548
# Catchment nr 124 has a given Ea of 1.8617418513689756 and Ea from P-Q of -1.0756010430247702, EI of -0.34890579172296765 and AI of 0.7006654697937612
# Catchment nr 125 has a given Ea of 1.610730117340292 and Ea from P-Q of 2.416182529335081, EI of 0.9028532843682023 and AI of 0.8332825851096425
# Catchment nr 126 has a given Ea of 1.8463872229465499 and Ea from P-Q of 1.4042020860495261, EI of 0.4985236701112 and AI of 0.8094518439658883
# Catchment nr 127 has a given Ea of 1.8784119947848763 and Ea from P-Q of 1.6365384615384506, EI of 0.5613014672607468 and AI of 0.7476984057424053
# Catchment nr 128 has a given Ea of 1.7107483702737898 and Ea from P-Q of 1.1586062581486263, EI of 0.3961421375915336 and AI of 0.7419504534243199
# Catchment nr 129 has a given Ea of 1.8540977835723649 and Ea from P-Q of -0.6014367666232152, EI of -0.20228737662957547 and AI of 0.7601289055699608
# Catchment nr 130 has a given Ea of 1.8216088657105662 and Ea from P-Q of 2.2703689700130365, EI of 0.7366220275990073 and AI of 0.7332578115548317
# Catchment nr 131 has a given Ea of 1.8048461538461502 and Ea from P-Q of 2.4031707953063837, EI of 0.8153198920533773 and AI of 0.7633538825883658
# Catchment nr 132 has a given Ea of 1.808877444589312 and Ea from P-Q of 2.893560625814846, EI of 0.917041301879399 and AI of 0.7162501880062762
# Catchment nr 133 has a given Ea of 1.78526988265972 and Ea from P-Q of 42.39355410691009, EI of 12.501314304718015 and AI of 0.6664449566415929
# Catchment nr 134 has a given Ea of 1.7847522816166943 and Ea from P-Q of 280.7736088657382, EI of 81.79681964035879 and AI of 0.6525715744246431
# Catchment nr 135 has a given Ea of 1.793973924380705 and Ea from P-Q of 144.89254237287918, EI of 47.9788851179967 and AI of 0.745052089966633
# Catchment nr 136 has a given Ea of 1.8155814863103 and Ea from P-Q of 477.77062972621474, EI of 157.90497393028255 and AI of 0.7337182746585083
# Catchment nr 137 has a given Ea of 1.7844602346805694 and Ea from P-Q of 280.8606166884808, EI of 80.88204000474016 and AI of 0.6479533946637855
# Catchment nr 138 has a given Ea of 1.8389556714471924 and Ea from P-Q of 2.223885267275092, EI of 0.8198799202672861 and AI of 0.8368810416587558
# Catchment nr 139 has a given Ea of 1.6655632333767953 and Ea from P-Q of 2.042324641460227, EI of 0.6858137186998425 and AI of 0.7354031839320118
# Catchment nr 140 has a given Ea of 1.8213298565841032 and Ea from P-Q of 14.016794002607526, EI of 4.676990440144868 and AI of 0.7507585891872515
# Catchment nr 141 has a given Ea of 1.617588005215123 and Ea from P-Q of 145.3625514993474, EI of 50.48391817565569 and AI of 0.7675254597378194
# Catchment nr 142 has a given Ea of 1.6144993481095202 and Ea from P-Q of 914.4959191655805, EI of 305.5256131260184 and AI of 0.7316611028253605
# Catchment nr 143 has a given Ea of 1.6756936114732706 and Ea from P-Q of -1.9199035202086154, EI of -0.7013187535421604 and AI of 0.8109405584580738
# Catchment nr 144 has a given Ea of 1.8313637548891883 and Ea from P-Q of 1.9289308996088737, EI of 0.630186991523622 and AI of 0.7448822251565368
# 59
