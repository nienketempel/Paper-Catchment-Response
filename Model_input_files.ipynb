# %% [markdown]
# # Load packages

# %%
from hydromt_wflow import WflowModel
import matplotlib.pyplot as plt 
import toml

import pandas as pd
# Out:
# C:\Users\Nienke Tempel\hydromt_wflow\hydromt_wflow\wflow.py:10: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# C:\Users\Nienke Tempel\anaconda3\envs\hydromt-wflow\lib\site-packages\hydromt\io.py:14: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   from . import raster, vector, gis_utils, merge

# %% [markdown]
# # Load model

# %%
root = r"C:\Users\Nienke Tempel\Documents\Thesis\11. Model\Model\for_nienke_mike\wflow_flextopo"
config_fn = "wflow_flextopo.toml"
mod = WflowModel(root = root, config_fn = config_fn, mode = "r")
ds = mod.staticmaps

# %%
plt.figure(); ds["sumax"].sel(classes="w").raster.mask_nodata().plot()
plt.figure(); ds["sumax"].sel(classes="p").raster.mask_nodata().plot()
plt.figure(); ds["sumax"].sel(classes="h").raster.mask_nodata().plot()

# %% [markdown]
# ## Change runtime

# %%
# Modify the starttime and endtime
mod.config['starttime'] = '1999-01-01T00:00:00'
mod.config['endtime'] = '2008-12-31T00:00:00'
# mod.config['starttime'] = '2009-01-01T00:00:00'
# mod.config['endtime'] = '2018-12-31T00:00:00'
mod.config
# Out:
# {'casename': 'wflow_meuse',
#  'calendar': 'proleptic_gregorian',
#  'starttime': '1999-01-01T00:00:00',
#  'endtime': '2008-12-31T00:00:00',
#  'time_units': 'days since 1900-01-01 00:00:00',
#  'timestepsecs': 86400,
#  'silent': False,
#  'loglevel': 'debug',
#  'path_log': 'log.txt',
#  'fews_run': False,
#  'state': {'path_input': 'instate/instates.nc',
#   'path_output': 'outstate/outstates.nc',
#   'lateral': {'river': {'reservoir': {'volume': 'volume_reservoir'},
#     'q': 'q_river',
#     'h': 'h_river',
#     'h_av': 'h_av_river'},
#    'land': {'q': 'q_land', 'h': 'h_land', 'h_av': 'h_av_land'}},
#   'vertical': {'snow': 'snow',
#    'snowwater': 'snowwater',
#    'interceptionstorage': 'interceptionstorage',
#    'hortonpondingstorage': 'hortonpondingstorage',
#    'hortonrunoffstorage': 'hortonrunoffstorage',
#    'rootzonestorage': 'rootzonestorage',
#    'faststorage': 'faststorage',
#    'slowstorage': 'slowstorage'}},
#  'input': {'path_forcing': '../inmaps/eobs_v20_1980_2018_corrP_remapnn_semisstonn.nc',
#   'path_static': '../staticmaps_flex_meuse.nc',
#   'gauges': 'wflow_gauges',
#   'ldd': 'wflow_ldd',
#   'river_location': 'wflow_river',
#   'subcatchment': 'wflow_subcatch',
#   'forcing': ['vertical.precipitation',
#    'vertical.temperature',
#    'vertical.potential_evaporation'],
#   'gauges_grdc': 'wflow_gauges_grdc',
#   'gauges_S01': 'wflow_gauges_S01',
#   'gauges_S02': 'wflow_gauges_S02',
#   'gauges_S03': 'wflow_gauges_S03',
#   'gauges_S04': 'wflow_gauges_S04',
#   'gauges_S05': 'wflow_gauges_S05',
#   'gauges_S06': 'wflow_gauges_S06',
#   'gauges_Sall': 'wflow_gauges_Sall',
#   'sub_S01': 'wflow_subcatch_S01',
#   'sub_S02': 'wflow_subcatch_S02',
#   'sub_S03': 'wflow_subcatch_S03',
#   'sub_S04': 'wflow_subcatch_S04',
#   'sub_S05': 'wflow_subcatch_S05',
#   'sub_S06': 'wflow_subcatch_S06',
#   'sub_Sall': 'wflow_subcatch_Sall',
#   'vertical': {'altitude': 'wflow_dem',
#    'potential_evaporation': 'PET',
#    'precipitation': 'P',
#    'temperature': 'TEMP',
#    'tt': 'tth',
#    'ttm': 'tmh',
#    'cfmax': 'fmh',
#    'whc': 'WHC',
#    'beta': 'beta',
#    'cap': 'cap',
#    'fdec': 'decf',
#    'fmax': 'fmax',
#    'imax': 'imax',
#    'ks': 'ks_mrch',
#    'perc': 'perc',
#    'srmax': 'sumax',
#    'hrufrac': 'hrufrac',
#    'lp': {'netcdf': {'variable': {'name': 'lp'}},
#     'scale': [0.4, 0.4, 0.4],
#     'offset': [0.0, 0.0, 0.0],
#     'class': ['h', 'p', 'w']},
#    'ds': {'netcdf': {'variable': {'name': 'd'}},
#     'scale': [1.2, 1.2, 1.0],
#     'offset': [0.0, 0.0, 0.0],
#     'class': ['h', 'p', 'w']},
#    'kf': {'netcdf': {'variable': {'name': 'kf'}},
#     'scale': [1.0, 3.0, 0.0],
#     'offset': [0.0, 0.0, 1.0416],
#     'class': ['h', 'p', 'w']},
#    'alfa': {'netcdf': {'variable': {'name': 'alfa'}},
#     'scale': 1.3,
#     'offset': 0,
#     'class': 'p'}},
#   'lateral': {'river': {'length': 'wflow_riverlength',
#     'slope': 'RiverSlope',
#     'width': 'wflow_riverwidth',
#     'bankfull_depth': 'RiverDepth',
#     'n': {'netcdf': {'variable': {'name': 'n_river_uniform'}},
#      'scale': 0,
#      'offset': 0.01},
#     'reservoir': {'area': 'ResSimpleArea',
#      'areas': 'wflow_reservoirareas',
#      'demand': 'ResDemand',
#      'locs': 'wflow_reservoirlocs',
#      'maxrelease': 'ResMaxRelease',
#      'maxvolume': 'ResMaxVolume',
#      'targetfullfrac': 'ResTargetFullFrac',
#      'targetminfrac': 'ResTargetMinFrac'}},
#    'land': {'n': 'n_uniform', 'slope': 'Slope'}}},
#  'model': {'type': 'flextopo',
#   'masswasting': True,
#   'snow': True,
#   'reinit': True,
#   'reservoirs': True,
#   'lakes': False,
#   'glacier': False,
#   'kin_wave_iteration': True,
#   'classes': ['h', 'p', 'w'],
#   'select_snow': ['common_snow_hbv'],
#   'select_interception': ['interception_overflow',
#    'interception_overflow',
#    'interception_overflow'],
#   'select_hortonponding': ['hortonponding_no_storage',
#    'hortonponding_no_storage',
#    'hortonponding_no_storage'],
#   'select_hortonrunoff': ['hortonrunoff_no_storage',
#    'hortonrunoff_no_storage',
#    'hortonrunoff_no_storage'],
#   'select_rootzone': ['rootzone_storage',
#    'rootzone_storage',
#    'rootzone_storage'],
#   'select_fast': ['fast_storage', 'fast_storage', 'fast_storage'],
#   'select_slow': ['common_slow_storage']},
#  'output': {'vertical': {}, 'lateral': {'river': {}, 'land': {}}},
#  'csv': {'path': 'output.csv',
#   'column': [{'header': 'Q',
#     'map': 'gauges',
#     'parameter': 'lateral.river.q_av'},
#    {'header': 'Q', 'map': 'gauges_S01', 'parameter': 'lateral.river.q_av'},
#    {'header': 'Q', 'map': 'gauges_S02', 'parameter': 'lateral.river.q_av'},
#    {'header': 'Q', 'map': 'gauges_S03', 'parameter': 'lateral.river.q_av'},
#    {'header': 'Q', 'map': 'gauges_S04', 'parameter': 'lateral.river.q_av'},
#    {'header': 'Q', 'map': 'gauges_S05', 'parameter': 'lateral.river.q_av'},
#    {'header': 'Q', 'map': 'gauges_S06', 'parameter': 'lateral.river.q_av'},
#    {'header': 'Qall', 'map': 'gauges_Sall', 'parameter': 'lateral.river.q_av'},
#    {'header': 'H', 'map': 'gauges_Sall', 'parameter': 'lateral.river.h_av'},
#    {'header': 'P',
#     'map': 'sub_S01',
#     'parameter': 'vertical.precipitation',
#     'reducer': 'mean'},
#    {'header': 'P',
#     'map': 'sub_S02',
#     'parameter': 'vertical.precipitation',
#     'reducer': 'mean'},
#    {'header': 'P',
#     'map': 'sub_S03',
#     'parameter': 'vertical.precipitation',
#     'reducer': 'mean'},
#    {'header': 'P',
#     'map': 'sub_S04',
#     'parameter': 'vertical.precipitation',
#     'reducer': 'mean'},
#    {'header': 'P',
#     'map': 'sub_S05',
#     'parameter': 'vertical.precipitation',
#     'reducer': 'mean'},
#    {'header': 'P',
#     'map': 'sub_S06',
#     'parameter': 'vertical.precipitation',
#     'reducer': 'mean'},
#    {'header': 'EP',
#     'map': 'sub_S01',
#     'parameter': 'vertical.potential_evaporation',
#     'reducer': 'mean'},
#    {'header': 'EP',
#     'map': 'sub_S02',
#     'parameter': 'vertical.potential_evaporation',
#     'reducer': 'mean'},
#    {'header': 'EP',
#     'map': 'sub_S03',
#     'parameter': 'vertical.potential_evaporation',
#     'reducer': 'mean'},
#    {'header': 'EP',
#     'map': 'sub_S04',
#     'parameter': 'vertical.potential_evaporation',
#     'reducer': 'mean'},
#    {'header': 'EP',
#     'map': 'sub_S05',
#     'parameter': 'vertical.potential_evaporation',
#     'reducer': 'mean'},
#    {'header': 'EP',
#     'map': 'sub_S06',
#     'parameter': 'vertical.potential_evaporation',
#     'reducer': 'mean'},
#    {'header': 'T',
#     'map': 'sub_S01',
#     'parameter': 'vertical.temperature',
#     'reducer': 'mean'},
#    {'header': 'T',
#     'map': 'sub_S02',
#     'parameter': 'vertical.temperature',
#     'reducer': 'mean'},
#    {'header': 'T',
#     'map': 'sub_S03',
#     'parameter': 'vertical.temperature',
#     'reducer': 'mean'},
#    {'header': 'T',
#     'map': 'sub_S04',
#     'parameter': 'vertical.temperature',
#     'reducer': 'mean'},
#    {'header': 'T',
#     'map': 'sub_S05',
#     'parameter': 'vertical.temperature',
#     'reducer': 'mean'},
#    {'header': 'T',
#     'map': 'sub_S06',
#     'parameter': 'vertical.temperature',
#     'reducer': 'mean'},
#    {'header': 'EA',
#     'map': 'sub_S01',
#     'parameter': 'vertical.actevap_m',
#     'reducer': 'mean'},
#    {'header': 'EA',
#     'map': 'sub_S02',
#     'parameter': 'vertical.actevap_m',
#     'reducer': 'mean'},
#    {'header': 'EA',
#     'map': 'sub_S03',
#     'parameter': 'vertical.actevap_m',
#     'reducer': 'mean'},
#    {'header': 'EA',
#     'map': 'sub_S04',
#     'parameter': 'vertical.actevap_m',
#     'reducer': 'mean'},
#    {'header': 'EA',
#     'map': 'sub_S05',
#     'parameter': 'vertical.actevap_m',
#     'reducer': 'mean'},
#    {'header': 'EA',
#     'map': 'sub_S06',
#     'parameter': 'vertical.actevap_m',
#     'reducer': 'mean'},
#    {'header': 'EI',
#     'map': 'sub_S01',
#     'parameter': 'vertical.intevap_m',
#     'reducer': 'mean'},
#    {'header': 'EI',
#     'map': 'sub_S02',
#     'parameter': 'vertical.intevap_m',
#     'reducer': 'mean'},
#    {'header': 'EI',
#     'map': 'sub_S03',
#     'parameter': 'vertical.intevap_m',
#     'reducer': 'mean'},
#    {'header': 'EI',
#     'map': 'sub_S04',
#     'parameter': 'vertical.intevap_m',
#     'reducer': 'mean'},
#    {'header': 'EI',
#     'map': 'sub_S05',
#     'parameter': 'vertical.intevap_m',
#     'reducer': 'mean'},
#    {'header': 'EI',
#     'map': 'sub_S06',
#     'parameter': 'vertical.intevap_m',
#     'reducer': 'mean'},
#    {'header': 'ER',
#     'map': 'sub_S01',
#     'parameter': 'vertical.rootevap_m',
#     'reducer': 'mean'},
#    {'header': 'ER',
#     'map': 'sub_S02',
#     'parameter': 'vertical.rootevap_m',
#     'reducer': 'mean'},
#    {'header': 'ER',
#     'map': 'sub_S03',
#     'parameter': 'vertical.rootevap_m',
#     'reducer': 'mean'},
#    {'header': 'ER',
#     'map': 'sub_S04',
#     'parameter': 'vertical.rootevap_m',
#     'reducer': 'mean'},
#    {'header': 'ER',
#     'map': 'sub_S05',
#     'parameter': 'vertical.rootevap_m',
#     'reducer': 'mean'},
#    {'header': 'ER',
#     'map': 'sub_S06',
#     'parameter': 'vertical.rootevap_m',
#     'reducer': 'mean'},
#    {'header': 'EH',
#     'map': 'sub_S01',
#     'parameter': 'vertical.hortonevap_m',
#     'reducer': 'mean'},
#    {'header': 'EH',
#     'map': 'sub_S02',
#     'parameter': 'vertical.hortonevap_m',
#     'reducer': 'mean'},
#    {'header': 'EH',
#     'map': 'sub_S03',
#     'parameter': 'vertical.hortonevap_m',
#     'reducer': 'mean'},
#    {'header': 'EH',
#     'map': 'sub_S04',
#     'parameter': 'vertical.hortonevap_m',
#     'reducer': 'mean'},
#    {'header': 'EH',
#     'map': 'sub_S05',
#     'parameter': 'vertical.hortonevap_m',
#     'reducer': 'mean'},
#    {'header': 'EH',
#     'map': 'sub_S06',
#     'parameter': 'vertical.hortonevap_m',
#     'reducer': 'mean'},
#    {'header': 'SW',
#     'map': 'sub_S01',
#     'parameter': 'vertical.snow',
#     'reducer': 'mean'},
#    {'header': 'SW',
#     'map': 'sub_S02',
#     'parameter': 'vertical.snow',
#     'reducer': 'mean'},
#    {'header': 'SW',
#     'map': 'sub_S03',
#     'parameter': 'vertical.snow',
#     'reducer': 'mean'},
#    {'header': 'SW',
#     'map': 'sub_S04',
#     'parameter': 'vertical.snow',
#     'reducer': 'mean'},
#    {'header': 'SW',
#     'map': 'sub_S05',
#     'parameter': 'vertical.snow',
#     'reducer': 'mean'},
#    {'header': 'SW',
#     'map': 'sub_S06',
#     'parameter': 'vertical.snow',
#     'reducer': 'mean'},
#    {'header': 'Sww',
#     'map': 'sub_S01',
#     'parameter': 'vertical.snowwater',
#     'reducer': 'mean'},
#    {'header': 'Sww',
#     'map': 'sub_S02',
#     'parameter': 'vertical.snowwater',
#     'reducer': 'mean'},
#    {'header': 'Sww',
#     'map': 'sub_S03',
#     'parameter': 'vertical.snowwater',
#     'reducer': 'mean'},
#    {'header': 'Sww',
#     'map': 'sub_S04',
#     'parameter': 'vertical.snowwater',
#     'reducer': 'mean'},
#    {'header': 'Sww',
#     'map': 'sub_S05',
#     'parameter': 'vertical.snowwater',
#     'reducer': 'mean'},
#    {'header': 'Sww',
#     'map': 'sub_S06',
#     'parameter': 'vertical.snowwater',
#     'reducer': 'mean'},
#    {'header': 'SI',
#     'map': 'sub_S01',
#     'parameter': 'vertical.interceptionstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SI',
#     'map': 'sub_S02',
#     'parameter': 'vertical.interceptionstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SI',
#     'map': 'sub_S03',
#     'parameter': 'vertical.interceptionstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SI',
#     'map': 'sub_S04',
#     'parameter': 'vertical.interceptionstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SI',
#     'map': 'sub_S05',
#     'parameter': 'vertical.interceptionstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SI',
#     'map': 'sub_S06',
#     'parameter': 'vertical.interceptionstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SR',
#     'map': 'sub_S01',
#     'parameter': 'vertical.srootzone_m',
#     'reducer': 'mean'},
#    {'header': 'SR',
#     'map': 'sub_S02',
#     'parameter': 'vertical.srootzone_m',
#     'reducer': 'mean'},
#    {'header': 'SR',
#     'map': 'sub_S03',
#     'parameter': 'vertical.srootzone_m',
#     'reducer': 'mean'},
#    {'header': 'SR',
#     'map': 'sub_S04',
#     'parameter': 'vertical.srootzone_m',
#     'reducer': 'mean'},
#    {'header': 'SR',
#     'map': 'sub_S05',
#     'parameter': 'vertical.srootzone_m',
#     'reducer': 'mean'},
#    {'header': 'SR',
#     'map': 'sub_S06',
#     'parameter': 'vertical.srootzone_m',
#     'reducer': 'mean'},
#    {'header': 'SH',
#     'map': 'sub_S01',
#     'parameter': 'vertical.hortonpondingstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SH',
#     'map': 'sub_S02',
#     'parameter': 'vertical.hortonpondingstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SH',
#     'map': 'sub_S03',
#     'parameter': 'vertical.hortonpondingstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SH',
#     'map': 'sub_S04',
#     'parameter': 'vertical.hortonpondingstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SH',
#     'map': 'sub_S05',
#     'parameter': 'vertical.hortonpondingstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SH',
#     'map': 'sub_S06',
#     'parameter': 'vertical.hortonpondingstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SHF',
#     'map': 'sub_S01',
#     'parameter': 'vertical.hortonrunoffstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SHF',
#     'map': 'sub_S02',
#     'parameter': 'vertical.hortonrunoffstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SHF',
#     'map': 'sub_S03',
#     'parameter': 'vertical.hortonrunoffstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SHF',
#     'map': 'sub_S04',
#     'parameter': 'vertical.hortonrunoffstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SHF',
#     'map': 'sub_S05',
#     'parameter': 'vertical.hortonrunoffstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SHF',
#     'map': 'sub_S06',
#     'parameter': 'vertical.hortonrunoffstorage_m',
#     'reducer': 'mean'},
#    {'header': 'SF',
#     'map': 'sub_S01',
#     'parameter': 'vertical.faststorage_m',
#     'reducer': 'mean'},
#    {'header': 'SF',
#     'map': 'sub_S02',
#     'parameter': 'vertical.faststorage_m',
#     'reducer': 'mean'},
#    {'header': 'SF',
#     'map': 'sub_S03',
#     'parameter': 'vertical.faststorage_m',
#     'reducer': 'mean'},
#    {'header': 'SF',
#     'map': 'sub_S04',
#     'parameter': 'vertical.faststorage_m',
#     'reducer': 'mean'},
#    {'header': 'SF',
#     'map': 'sub_S05',
#     'parameter': 'vertical.faststorage_m',
#     'reducer': 'mean'},
#    {'header': 'SF',
#     'map': 'sub_S06',
#     'parameter': 'vertical.faststorage_m',
#     'reducer': 'mean'},
#    {'header': 'SS',
#     'map': 'sub_S01',
#     'parameter': 'vertical.slowstorage',
#     'reducer': 'mean'},
#    {'header': 'SS',
#     'map': 'sub_S02',
#     'parameter': 'vertical.slowstorage',
#     'reducer': 'mean'},
#    {'header': 'SS',
#     'map': 'sub_S03',
#     'parameter': 'vertical.slowstorage',
#     'reducer': 'mean'},
#    {'header': 'SS',
#     'map': 'sub_S04',
#     'parameter': 'vertical.slowstorage',
#     'reducer': 'mean'},
#    {'header': 'SS',
#     'map': 'sub_S05',
#     'parameter': 'vertical.slowstorage',
#     'reducer': 'mean'},
#    {'header': 'SS',
#     'map': 'sub_S06',
#     'parameter': 'vertical.slowstorage',
#     'reducer': 'mean'},
#    {'header': 'Sr_over_srmax_p',
#     'map': 'sub_S06',
#     'parameter': 'vertical.srootzone_over_srmax',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'Sr_over_srmax_m',
#     'map': 'sub_S01',
#     'parameter': 'vertical.srootzone_over_srmax_m',
#     'reducer': 'mean'},
#    {'header': 'Sr_over_srmax_m',
#     'map': 'sub_S02',
#     'parameter': 'vertical.srootzone_over_srmax_m',
#     'reducer': 'mean'},
#    {'header': 'Sr_over_srmax_m',
#     'map': 'sub_S03',
#     'parameter': 'vertical.srootzone_over_srmax_m',
#     'reducer': 'mean'},
#    {'header': 'Sr_over_srmax_m',
#     'map': 'sub_S04',
#     'parameter': 'vertical.srootzone_over_srmax_m',
#     'reducer': 'mean'},
#    {'header': 'Sr_over_srmax_m',
#     'map': 'sub_S05',
#     'parameter': 'vertical.srootzone_over_srmax_m',
#     'reducer': 'mean'},
#    {'header': 'Sr_over_srmax_m',
#     'map': 'sub_S06',
#     'parameter': 'vertical.srootzone_over_srmax_m',
#     'reducer': 'mean'},
#    {'header': 'Qftotal',
#     'map': 'sub_S06',
#     'parameter': 'vertical.qfast_tot',
#     'reducer': 'mean'},
#    {'header': 'Qh',
#     'map': 'sub_S06',
#     'parameter': 'vertical.qhortonpond',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'Qhf',
#     'map': 'sub_S06',
#     'parameter': 'vertical.qhortonrun',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'Qs',
#     'map': 'sub_S01',
#     'parameter': 'vertical.qslow',
#     'reducer': 'mean'},
#    {'header': 'Qs',
#     'map': 'sub_S06',
#     'parameter': 'vertical.qslow',
#     'reducer': 'mean'},
#    {'header': 'Qcap',
#     'map': 'sub_S06',
#     'parameter': 'vertical.qcapillary_m',
#     'reducer': 'mean'},
#    {'header': 'QfP',
#     'map': 'sub_S06',
#     'parameter': 'vertical.qfast',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'QfW',
#     'map': 'sub_S06',
#     'parameter': 'vertical.qfast',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'QfH',
#     'map': 'sub_S06',
#     'parameter': 'vertical.qfast',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'EaH',
#     'map': 'sub_S06',
#     'parameter': 'vertical.actevap',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'EaP',
#     'map': 'sub_S06',
#     'parameter': 'vertical.actevap',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'EaW',
#     'map': 'sub_S06',
#     'parameter': 'vertical.actevap',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'ErH',
#     'map': 'sub_S06',
#     'parameter': 'vertical.rootevap',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'ErP',
#     'map': 'sub_S06',
#     'parameter': 'vertical.rootevap',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'ErW',
#     'map': 'sub_S06',
#     'parameter': 'vertical.rootevap',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'percentageP',
#     'map': 'sub_S01',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'percentageW',
#     'map': 'sub_S01',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'percentageH',
#     'map': 'sub_S01',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'percentageP',
#     'map': 'sub_S06',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'percentageW',
#     'map': 'sub_S06',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'percentageH',
#     'map': 'sub_S06',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'percentageP',
#     'map': 'sub_Sall',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'percentageW',
#     'map': 'sub_Sall',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'percentageH',
#     'map': 'sub_Sall',
#     'parameter': 'vertical.hrufrac',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'QfP',
#     'map': 'sub_S01',
#     'parameter': 'vertical.qfast',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'QfW',
#     'map': 'sub_S01',
#     'parameter': 'vertical.qfast',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'QfH',
#     'map': 'sub_S01',
#     'parameter': 'vertical.qfast',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'SfP',
#     'map': 'sub_S01',
#     'parameter': 'vertical.faststorage',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'SfW',
#     'map': 'sub_S01',
#     'parameter': 'vertical.faststorage',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'SfH',
#     'map': 'sub_S01',
#     'parameter': 'vertical.faststorage',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'SfP',
#     'map': 'sub_S06',
#     'parameter': 'vertical.faststorage',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'SfW',
#     'map': 'sub_S06',
#     'parameter': 'vertical.faststorage',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'SfH',
#     'map': 'sub_S06',
#     'parameter': 'vertical.faststorage',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'kfP',
#     'map': 'sub_Sall',
#     'parameter': 'vertical.kf',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'kfW',
#     'map': 'sub_Sall',
#     'parameter': 'vertical.kf',
#     'reducer': 'mean',
#     'class': 'w'},
#    {'header': 'kfH',
#     'map': 'sub_Sall',
#     'parameter': 'vertical.kf',
#     'reducer': 'mean',
#     'class': 'h'},
#    {'header': 'wbtot',
#     'map': 'sub_S06',
#     'parameter': 'vertical.wb_tot',
#     'reducer': 'mean'},
#    {'header': 'wbSi_p',
#     'map': 'sub_S06',
#     'parameter': 'vertical.wb_interception',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'wbShf_p',
#     'map': 'sub_S06',
#     'parameter': 'vertical.wb_hortonrunoff',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'wbSh_p',
#     'map': 'sub_S06',
#     'parameter': 'vertical.wb_hortonponding',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'wbSr_p',
#     'map': 'sub_S06',
#     'parameter': 'vertical.wb_rootzone',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'wbSf_p',
#     'map': 'sub_S06',
#     'parameter': 'vertical.wb_fast',
#     'reducer': 'mean',
#     'class': 'p'},
#    {'header': 'wbSs',
#     'map': 'sub_S06',
#     'parameter': 'vertical.wb_slow',
#     'reducer': 'mean'},
#    {'header': 'to_river_land',
#     'map': 'gauges_S06',
#     'parameter': 'lateral.land.to_river'},
#    {'header': 'land_inwater',
#     'map': 'sub_S06',
#     'parameter': 'lateral.land.inwater',
#     'reducer': 'mean'}]}}

# %% [markdown]
# ## Load Srmax values

# %%
gdf = mod.staticgeoms["subcatch_Sall"].copy()
gdf.index = gdf["wflow_subcatch_Sall"]
gdf = gdf.drop(columns="wflow_subcatch_Sall")

# %%
gdf
wflow_ids = gdf.loc[gdf['geometry'] != None].index.values

# %%
# mod.staticgeoms["subcatch_Sall"].plot(edgecolor="k");

# %%
vs = [103,104]
print(vs)
# Out:
# [103, 104]

# %%
for v in vs:
    SRmax_v = pd.read_csv(f'C:/Users/Nienke Tempel/Documents/Thesis/6. Code/9_TOML/1_Input/B2/SRmax{v}.csv')
    for i in range(len(gdf)):
        wflow = gdf.index[i]
        wflow_int=int(wflow)
        subcatch = gdf.iloc[i]
        if wflow_int in wflow_ids:
            if wflow_int in SRmax_v['WFLOW'].values:
                gdf.loc[wflow_int, 'sumax_w'] = SRmax_v.loc[SRmax_v['WFLOW'] == wflow_int, 'Sr_2'].values[0]
                gdf.loc[wflow_int, 'sumax_p'] = SRmax_v.loc[SRmax_v['WFLOW'] == wflow_int, 'Sr_2'].values[0]
                gdf.loc[wflow_int, 'sumax_h'] = SRmax_v.loc[SRmax_v['WFLOW'] == wflow_int, 'Sr_20'].values[0]

            else:
                gdf.loc[wflow_int, 'sumax_w'] = SRmax_v.loc[SRmax_v['WFLOW'] == 16, 'Sr_2'].values[0]
                gdf.loc[wflow_int, 'sumax_p'] = SRmax_v.loc[SRmax_v['WFLOW'] == 16, 'Sr_2'].values[0]
                gdf.loc[wflow_int, 'sumax_h'] = SRmax_v.loc[SRmax_v['WFLOW'] == 16, 'Sr_20'].values[0]
                
    sumax_w = ds["sumax"].raster.rasterize(gdf, col_name="sumax_w")
    sumax_p = ds["sumax"].raster.rasterize(gdf, col_name="sumax_p")
    sumax_h = ds["sumax"].raster.rasterize(gdf, col_name="sumax_h")

    #make a copy of sumax maps in staticmaps
    sumax_v_classes = ds["sumax"].copy()
    
    #overwrite sumax plateau class with new values
    sumax_v_classes.loc[dict(classes="p")] = sumax_p

    #overwrite sumax wetland class with new values
    sumax_v_classes.loc[dict(classes="w")] = sumax_w

    #overwrite sumax hillslope class with new values
    sumax_v_classes.loc[dict(classes="h")] = sumax_h
    
    #add the new sumax maps to the staticmaps
    sumax_v_classes.name = "sumax_v"
    
    mod.set_staticmaps(sumax_v_classes)
    mod.set_config("input.vertical.srmax","sumax_v")
    mod.set_config("input.path_static", "staticmaps_flex_meuse.nc")
    mod.set_config("input.path_forcing", "../for_nienke_mike/inmaps/eobs_v20_1980_2018_corrP_remapnn_semisstonn.nc")
    mod.staticmaps.raster.set_crs("EPSG:4326")
    
    mod.set_root(f"C:/Users/Nienke Tempel/Documents/Thesis/11. Model/Model/flextopo_B2_{v}")
    mod.write_staticmaps()
    mod.write_config()
    mod.write_staticgeoms()

# %%
# mod.staticmaps

# %% [markdown]
# ## Check if maps is right

# %%
plt.figure(); sumax_v_classes.sel(classes="w").raster.mask_nodata().plot()
plt.figure(); sumax_v_classes.sel(classes="p").raster.mask_nodata().plot()
plt.figure(); sumax_v_classes.sel(classes="h").raster.mask_nodata().plot()
